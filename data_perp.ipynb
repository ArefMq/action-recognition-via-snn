# %%
from cache_generator import data_loader, cache_data

CACHE_FOLDER_PATH = "/Users/aref/dvs-dataset/Cached/"
DATASET_FOLDER_PATH = "/Users/aref/dvs-dataset/DvsGesture/"

cache_data('test', DATASET_FOLDER_PATH, CACHE_FOLDER_PATH)
# Out:
#      ------------------------- 1 out of 24 -------------------------
# ---> reading "/Users/aref/dvs-dataset/DvsGesture/user24_fluorescent.aedat"
# ---> pre-processing file...
# ---> processing file...
# 8636371165
# 8636381065
# 8636390965
# 8636400865
# 8636410765
# 8636420665
# 8636430565
# 8636440465
# 8636450365
# 8636460265
# 8636470165
# 8636480065
# 8636489965
# 8636499865
# 8636509765
# 8636519665
# 8636529565
# 8636539465
# 8636549365
# 8636559265
# 8636569165
# 8636579065
# 8636588965
# 8636598865
# 8636608765
# 8636618665
# 8636628565
# 8636638465
# 8636648365
# 8636658265
# 8636668165
# 8636678065
# 8636687965
# 8636697865
# 8636707765
# 8636717665
# 8636727565
# 8636737465
# 8636747365
# 8636757265
# 8636767165
# 8636777065
# 8636786965
# 8636796865
# 8636806765
# 8636816665
# 8636826565
# 8636836465
# 8636846365
# 8636856265
# 8636866165
# 8636876065
# 8636885965
# 8636895865
# 8636905765
# 8636915665
# 8636925565
# 8636935465
# 8636945365
# 8636955265
# 8636965165
# 8636975065
# 8636984965
# 8636994865
# 8637004765
# 8637014665
# 8637024565
# 8637034465
# 8637044365
# 8637054265
# 8637064165
# 8637074065
# 8637083965
# 8637093865
# 8637103765
# 8637113665
# 8637123565
# 8637133465
# 8637143365
# 8637153265
# 8637163165
# 8637173065
# 8637182965
# 8637192865
# 8637202765
# 8637212665
# 8637222565
# 8637232465
# 8637242365
# 8637252265
# 8637262165
# 8637272065
# 8637281965
# 8637291865
# 8637301765
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-3488f7374cce> in <module>()
#       5
#       6 # data_loader
# ----> 7 cache_data('test', DATASET_FOLDER_PATH, CACHE_FOLDER_PATH)
#
# /Users/aref/Workspace/action-recognition-via-snn/cache_generator.py in cache_data(trail, dataset_folder_path, output_data_path, image_reduce_factor, frame_length_us, frame_count, batch_size, frame_shuffle)
#     187         counter += 1
#     188         print('     ------------------------- %d out of %d -------------------------' % (counter, len(file_list)))
# --> 189         read_and_process_file(file_name_set, trail, counter, image_reduce_factor, frame_length_us, output_data_path)
#     190         notify('chunk done: %d / %d' % (counter, len(file_list)))
#     191     notify('all done')
#
# /Users/aref/Workspace/action-recognition-via-snn/cache_generator.py in read_and_process_file(file_name, trail, counter, image_reduce_factor, frame_length_us, output_data_path)
#     142     print('---> processing file...')
#     143     x_train, y_train = serialize_events(np.array(ev_x), np.array(ev_y), np.array(ev_z), image_reduce_factor,
# --> 144                                         frame_length_us)
#     145
#     146     print('---> saving file...')
#
# /Users/aref/Workspace/action-recognition-via-snn/cache_generator.py in serialize_events(x_data, y_data, ev_times, image_reduce_factor, frame_length_us)
#      89         ev_ub = ev_times < (current_time + frame_length_us)
#      90
# ---> 91         event_x = x_data[ev_lb & ev_ub, :]
#      92         event_y = y_data[ev_lb & ev_ub]
#      93
#
# KeyboardInterrupt:
